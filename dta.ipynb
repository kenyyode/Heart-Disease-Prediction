# %%
import pandas as pd

# %%
df = pd.read_excel('Apocolypse Food Prep - Power Query Editor Tutorial.xlsx', sheet_name=2)

# %%
df.head(3)
# Out:
#   Apocolypse Food Prep Overview Unnamed: 1           Unnamed: 2  \
# 0                           NaN        NaN                  NaN
# 1                           NaN        NaN                  NaN
# 2                      Location   Products  2022-01-01 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5   Unnamed: 6
# 0                  NaN                  NaN                  NaN          NaN
# 1                  NaN                  NaN                  NaN          NaN
# 2  2022-02-01 00:00:00  2022-03-01 00:00:00  2022-04-01 00:00:00  Grand Total

# %%
df.drop([0,1], axis=0, inplace=True)

# %%
new_header = df.iloc[0]

# %%
df = df[1:]

# %%
df.columns = new_header

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(2)
# Out:
#   Location           Products 2022-01-01 00:00:00 2022-02-01 00:00:00  \
# 0   Costco     Bottled Water                 4.25                4.49
# 1   Costco  Canned Vegetables                0.85                0.85
#
#   2022-03-01 00:00:00 2022-04-01 00:00:00 Grand Total
# 0                 4.8                4.89       18.43
# 1                0.85                0.85         3.4

# %%
df.columns.name = ' '

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Location             27 non-null     object
#  1   Products             31 non-null     object
#  2   2022-01-01 00:00:00  31 non-null     object
#  3   2022-02-01 00:00:00  19 non-null     object
#  4   2022-03-01 00:00:00  31 non-null     object
#  5   2022-04-01 00:00:00  19 non-null     object
#  6   Grand Total          31 non-null     object
# dtypes: object(7)
# memory usage: 1.8+ KB

# %%
df.isnull().sum()
# Out:
#
# Location                0
# Products                0
# 2022-01-01 00:00:00     0
# 2022-02-01 00:00:00    12
# 2022-03-01 00:00:00     0
# 2022-04-01 00:00:00    12
# Grand Total             0
# dtype: int64

# %%
df.dropna(subset=['Location'], inplace=True)

# %%
df
# Out:
#    Location           Products 2022-01-01 00:00:00 2022-02-01 00:00:00  \
# 0    Costco     Bottled Water                 4.25                4.49
# 1    Costco  Canned Vegetables                0.85                0.85
# 2    Costco        Dried Beans               20.99               22.99
# 3    Costco          Duct Tape                   5                 NaN
# 4    Costco         Flashlight                  13                 NaN
# 5    Costco               Milk                 2.3                 2.4
# 6    Costco               Rice                  23               23.99
# 7    Costco               Rope                13.5                 NaN
# 8    Costco       Water Filter                  29                 NaN
# 10   Target     Bottled Water                 4.99                5.15
# 11   Target  Canned Vegetables                0.65                0.69
# 12   Target        Dried Beans               23.99               24.99
# 13   Target          Duct Tape                   6                 NaN
# 14   Target         Flashlight                12.5                 NaN
# 15   Target               Milk                 2.2                2.45
# 16   Target               Rice               22.99               23.25
# 17   Target               Rope                  15                 NaN
# 18   Target       Water Filter                  38                 NaN
# 20  Walmart     Bottled Water                    5                5.25
# 21  Walmart  Canned Vegetables                0.65                0.75
# 22  Walmart        Dried Beans               22.99               23.99
# 23  Walmart          Duct Tape                   5                 NaN
# 24  Walmart         Flashlight                  10                 NaN
# 25  Walmart               Milk                   2                 2.1
# 26  Walmart               Rice                  25               25.75
# 27  Walmart               Rope                  14                 NaN
# 28  Walmart       Water Filter                  39                 NaN
#
#    2022-03-01 00:00:00 2022-04-01 00:00:00 Grand Total
# 0                  4.8                4.89       18.43
# 1                 0.85                0.85         3.4
# 2                22.99               23.99       90.96
# 3                 5.25                 NaN       10.25
# 4                   13                 NaN          26
# 5                  2.5                 2.7         9.9
# 6                24.99               25.25       97.23
# 7                   14                 NaN        27.5
# 8                   31                 NaN          60
# 10                5.25                5.35       20.74
# 11                0.74                0.79        2.87
# 12               25.45               25.79      100.22
# 13                6.25                 NaN       12.25
# 14               12.75                 NaN       25.25
# 15                 2.7                   3       10.35
# 16               24.25               24.75       95.24
# 17               15.25                 NaN       30.25
# 18                  39                 NaN          77
# 20                5.45                5.75       21.45
# 21                0.85                   1        3.25
# 22               24.25               24.49       95.72
# 23                 5.5                 NaN        10.5
# 24                  11                 NaN          21
# 25                 2.4                 2.9         9.4
# 26               26.99               26.99      104.73
# 27                14.5                 NaN        28.5
# 28                  39                 NaN          78

# %%
df_melted = df.melt(
    id_vars=['Location', 'Product']
)
